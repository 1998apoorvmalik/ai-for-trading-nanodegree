# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1, 1000)
y = pd.Series(np.cumsum(x[:-1]))
x =pd.Serires9np.cumsum(x[1:])

# %%
plt.

# %%
from statsmodels.graphics.tsaplots import plot_pacf
_ = plot_pacf(x-y, lags=10)
